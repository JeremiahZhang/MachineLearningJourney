# %% [markdown]
# # Project
#
# 我得一个一个项目进行，应用机器学习的理念，给自己点时间，看看这到底是多么有趣。
#
# 再次开启 Machine Learning 的星际迷航，enterprises 会驶向以下几个星球：
#
# star 1. 问题的定义，这是离总部最近的一个星球，也是必须去探索的一个星球，这有搞明白这个星球，获得继续探索的补给，我们才能继续。
# star 2. prepare data. 到达star 2 是为了获得我们探索需要的原始数据，进而进行数据的处理，特征的选择与转化，使得数据利于我们在未来探索。
# star 3. Spot check algorithms. 在这个星球上，我们需要选择一些算法，对处理好的数据进行探索分析，对比算法的效果，进行算法的评估
# star 4. Improve Results. 此星球是为了探索更好的分析效果。
# finial. you need to return back. 这里就得回总部汇报你的探索旅程啦，分享给你的同事战友们吧。
#
# ok let's go.

# %% [markdown]
# ## 第一站 Problem definition
#
# 此次，我们将探索 Boston House Price dataset, dataset的来源是 https://archive.ics.uci.edu/ml/datasets/Housing,
#
# > Dataset infomation: Concerns housing values in suburbs of Boston.
#
# ok, 那么这些数据的特征有哪些呢？在上面的link 中已经有介绍了
#
# > Attribute Information:
#
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner-occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-value property-tax rate per $10,000
#
# 11. PTRATIO: pupil-teacher ratio by town
# 12. B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
# 14. MEDV: Median value of owner-occupied homes in $1000's  （这个是 output attribute）
#
# 这些特征到底是什么梗！！！！不怎么清楚，那么先放一放，就知道这些是特征来着，具体什么特征，日后再来。
#
# 那么，我们到底要干嘛？
#
# 预测预测什么呢？房间！也就是，类似回归分析。根据已知的数据，预测房价。已知x,y,求f(x,y).这样一个预测模型。
# 那么如何直接应用machine learning 呢？
#
# go next：来看看我们的数据到底是什么样的。
#
# ### Load the dataset

# %%
# load libraries
import pandas
import numpy
import matplotlib.pyplot as plt

from pandas.tools.plotting import scatter_matrix

from sklearn.preprocessing import StandardScaler
from sklearn import cross_validation

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.metrics import mean_squared_error

# %%
# load dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", 
        "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

dataset = pandas.read_csv(url, delim_whitespace=True, names=names)

# %% [raw]
# 不懂 delim_whitespace 是吧，那么就查 pandas doc：
#
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv
#
# 数据load 好了， 那么就让我们一起来 peek 吧

# %% [markdown]
# ### analyze data

# %%
# shape
print (dataset.shape)
# Out:
# (506, 14)

# %%
ok 可以看到 有506组数据，每组数据有14个特征，这14个特征在上文中也已经介绍过了

# %%
# type
print (dataset.dtypes)
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# head
dataset.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
# descriptions 
pandas.set_option('precision', 1)

dataset.describe()
# Out:
#           CRIM     ZN  INDUS     CHAS    NOX     RM    AGE    DIS    RAD  \
# count  5.1e+02  506.0  506.0  5.1e+02  506.0  506.0  506.0  506.0  506.0
# mean   3.6e+00   11.4   11.1  6.9e-02    0.6    6.3   68.6    3.8    9.5
# std    8.6e+00   23.3    6.9  2.5e-01    0.1    0.7   28.1    2.1    8.7
# min    6.3e-03    0.0    0.5  0.0e+00    0.4    3.6    2.9    1.1    1.0
# 25%    8.2e-02    0.0    5.2  0.0e+00    0.4    5.9   45.0    2.1    4.0
# 50%    2.6e-01    0.0    9.7  0.0e+00    0.5    6.2   77.5    3.2    5.0
# 75%    3.7e+00   12.5   18.1  0.0e+00    0.6    6.6   94.1    5.2   24.0
# max    8.9e+01  100.0   27.7  1.0e+00    0.9    8.8  100.0   12.1   24.0
#
#          TAX  PTRATIO      B  LSTAT   MEDV
# count  506.0    506.0  506.0  506.0  506.0
# mean   408.2     18.5  356.7   12.7   22.5
# std    168.5      2.2   91.3    7.1    9.2
# min    187.0     12.6    0.3    1.7    5.0
# 25%    279.0     17.4  375.4    6.9   17.0
# 50%    330.0     19.1  391.4   11.4   21.2
# ...

# %%
# correlations between attributes

pandas.set_option('precision', 3)
correlations = dataset.corr(method="pearson")

correlations
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     1.000 -0.200  0.407 -0.056  0.421 -0.219  0.353 -0.380  0.626  0.583
# ZN      -0.200  1.000 -0.534 -0.043 -0.517  0.312 -0.570  0.664 -0.312 -0.315
# INDUS    0.407 -0.534  1.000  0.063  0.764 -0.392  0.645 -0.708  0.595  0.721
# CHAS    -0.056 -0.043  0.063  1.000  0.091  0.091  0.087 -0.099 -0.007 -0.036
# NOX      0.421 -0.517  0.764  0.091  1.000 -0.302  0.731 -0.769  0.611  0.668
# RM      -0.219  0.312 -0.392  0.091 -0.302  1.000 -0.240  0.205 -0.210 -0.292
# AGE      0.353 -0.570  0.645  0.087  0.731 -0.240  1.000 -0.748  0.456  0.506
# DIS     -0.380  0.664 -0.708 -0.099 -0.769  0.205 -0.748  1.000 -0.495 -0.534
# RAD      0.626 -0.312  0.595 -0.007  0.611 -0.210  0.456 -0.495  1.000  0.910
# TAX      0.583 -0.315  0.721 -0.036  0.668 -0.292  0.506 -0.534  0.910  1.000
# PTRATIO  0.290 -0.392  0.383 -0.122  0.189 -0.356  0.262 -0.232  0.465  0.461
# ...
